# %% [markdown]
# # Libraries

# %%
from collections import Counter
from gensim.models import Word2Vec, KeyedVectors
import pandas as pd
import nltk
import tqdm

# %% [markdown]
# # Downloads

# %%
# nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %% [markdown]
# # Data Manipulations

# %%
# open file
with open('../inputs/corpus_all.txt', mode='r', encoding='utf-8') as file:
    # read and store all text data to data variable
    data = file.read()

# %%
# find the length of the data
print(f"The length of the whole data: {len(data)}")

# file is too large and therefore, only some portion will be used
section = data[:10001]

# verify the data
print(section)
# Out:
# The length of the whole data: 1293114312
# kitabın üz qabığında şəkilləri verilmiş gənc qadınların hər ikisi müsəlmandır . onlar çoxsaylı ərəb mənşəli amerikalıların yaşadığı icmada miçiqanda  detroyt michigan detroityaxınlığında yaşayırlar . onların hər biri inamlarını özünəməxsus tərzdə  biri müasir digəri isə ənənəvi geyimləri ilə ifadə edir . burada  basketbol meydançasında onlar çılğıncasına yarışırlar . bu idman növü həm fərdi qabiliyyət həm də bütün komandanın səyini tələb edir . onlar bu kitabda digər kişilər qadınlar və uşaqlarla birlikdə amerika müsəlmanlarının gündəlik həyat tərzini nümayiş etdirirlər . c united states department of state bureau international information programs being muslim in america elmi redaktor və layihənin koordinatoru nailə süleymanova ilahiyyat üzrə fəlsəfə doktoru tərcüməçi xumar hüseynova redaktorlar elza ismayılova xəzər universitəsi filologiya üzrə fəlsəfə doktoru cabir məmmədov kompüter dizayn zakir n . yusifoğlu korrektor günay israfilova bu layihə amerika birləşmiş ştatlarının səfirlyi ilə bağlanmış qrant sazişi əsasında həyata keçirilib this project as funded through a grant agreement ith the embassy of the united states of america ilkin nəşriyyat global publishing solutions tərəfinin icazəsi ilə tərcümə edilmiş və nəşr olunmuşdur ingilis dilindən tərcümə khazar university press  isbn  amerika müsəlmanları . bakı xəzər universitəsi nəşriyyatı  .  səh .  . islam .  . müsəlmanlarabş .  . dc birləşmiş ştatların dövlət departamenti beynəlxalq informasiya proqramları bürosu  giriş mən müsəlman ruhlu amerikalıyam  fotooçerk amerikada həyat qurmaq  profillər gənc müsəlmanlar öz sözlərini deyirlər  mənbələr statistik portret  yaxınlıqdakı məscidlər  mühüm tarixi hadisələr  biblioqrafiya  əlavə bilirdinizmi miniafişa amerika müsəlmanlari m ən amerikanı x ə y a l l a r ı m d a olduqca gözəl təsəvvür etdiy imə görə dey i l  onun mənə  hindistandan olan müsəlman övladına amerikanın ink işaf ında işt i rak etməyə onun ç içəklənməsi yolunda iz lər qoymağa həyat ında nə isə b ir ro l oynamağa imkan verdiy inə görə sevirəm . amerikada i lk məskunlaşan avropal ı lar a i ləs inə mənsub con vinsrop  john inthropbu f ikr i dəstəkləy ir . amerikanın həyat ındakı ro lunu həmvətənlər inə göstərərkən con onlar ın cəmiyyət in in yüksəkl ikdə yer ləşən və bütün dünyaya mayak o lacaq bir şəhərə bənzəyəcəyin i deyird i . bu ümidin kökü onun xr ist ian o lmasında id i . şübhəsiz k i  con öz şəhər in i mərkəz ində hündür qül lə l i k i l səs i o lan b ir şəhər k imi təsəvvür edirdi . çoxmi l lət l i o lmamışdan əvvəl amerika əsr lər boyu son dərəcə d in i b i r ö lkə o lmuşdur . doğrudan da b iz qərbdə dinə ən sədaqət l i  e ləcə də müxtəl i f d in lərə ən çox et iqad edi ld iy i b i r ö lkəyik . indi yüksəkl ikdə olan şəhər k i l səs in in qül ləs i müsəlman məscid lər in in minarələr i  yəhudi s inaqoqlar ın ın ibrani ə lyazmalar ı  buddist sanqalar ın zümzüməsi  h indu məbədlər i i lə əhatə mən müsəlman ruhlu amerıkalıyam əbu patel  olunmuşdur . bu b ir faktdır k i  haz ırda amerikada müsəlmanlar amerikal ı lar ın təs is və etiqad etdiy i yepiskopal k i l sənin üzv lər indən daha çoxdur . yüz i l bundan əvvəl afr ika mənşəl i görkəml i amerika a l imi u . e . b . du bois  . e . b . du bois əsr in əsas probleminin rəng problemi o lacağı barədə xəbərdar l ıq etmişdi . c i əsrdə isə onun yer in i d in i inanclar ın tutacağı eht imal o lunurdu . mənim ölkəmi  amerikanı  mənim din imi  is lamı və al lahın h imayəsində yaşayan bütün insanlar ı narahat edən məsələ bunlar o la b i lərdi  müxtəl i f d inə mənsub insanlar b irb ir i i lə necə üns iyyət quracaqlar k i lsə qül ləs i  minarə s inaqoq məbəd və sanqalar yüksəkl ikdə yer ləşən yeni şəhərdə bölüşməyi öyrənə bi ləcəklərmi düşünürəm ki  dözümlülük və hörməti özündə toplayan amerika ənənəsi bu məsələnin həl l inə xüsus i b i r töhfə verəcəkdir . amerika daha çox başqa yer lərdən olan insanlar ın böyük bir toplusudur . bu insanlara öz lər inə məxsus dəyər lər əsas ında amerika ənənəsinə töhfə verməyə və a ...

# %%
# tokenize selected section to its sentences
sentences = nltk.sent_tokenize(section)

# tokenize each sentence to its words
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
# create counter
word_to_frequency = Counter()

# count the instance of each word in the section
for tokenized_sentence in tokenized_sentences:
    word_to_frequency.update(tokenized_sentence)

# %%
# list counter in descending order
word_to_frequency.most_common()
# Out:
# [('.', 93),
#  ('i', 68),
#  ('və', 34),
#  ('l', 32),
#  ('in', 21),
#  ('b', 16),
#  ('bir', 15),
#  ('amerika', 14),
#  ('müsəlman', 14),
#  ('ın', 14),
#  ('bu', 13),
#  ('ı', 13),
#  ('o', 12),
#  ('inə', 10),
#  ('onlar', 9),
#  ('onların', 9),
#  ('isə', 9),
#  ('həm', 9),
#  ('də', 9),
#  ('d', 9),
#  ('k', 9),
#  ('mənim', 9),
#  ('yeni', 9),
#  ('hər', 8),
#  ('lər', 8),
#  ('lar', 8),
#  ('həyat', 7),
#  ('a', 7),
#  ('ir', 7),
#  ('insanlar', 7),
#  ('ruhum', 7),
#  ('r', 6),
#  ('yer', 6),
#  ('lə', 6),
#  ('böyük', 6),
#  ('amerikalı', 6),
#  ('ilə', 5),
#  ('amerikada', 5),
#  ('öz', 5),
#  ('onun', 5),
#  ('olan', 5),
#  ('amerikanın', 5),
#  ('ında', 5),
#  ('f', 5),
#  ('ikdə', 5),
#  ('çox', 5),
#  ('üçün', 5),
#  ('asiya', 5),
#  ('birləşmiş', 4),
#  ('mən', 4),
#  ('görə', 4),
#  ('yüksəkl', 4),
#  ('id', 4),
#  ('şəhər', 4),
#  ('əsr', 4),
#  ('e', 4),
#  ('s', 4),
#  ('əsas', 4),
#  ('əsrdə', 4),
#  ('buraya', 4),
#  ('bəziləri', 4),
#  ('amerikalılar', 4),
#  ('edir', 3),
#  ('bütün', 3),
#  ('digər', 3),
#  ('of', 3),
#  ('üzrə', 3),
#  ('ruhlu', 3),
#  ('müsəlmanlar', 3),
#  ('ən', 3),
#  ('ə', 3),
#  ('etdiy', 3),
#  ('ink', 3),
#  ('işaf', 3),
#  ('ç', 3),
#  ('ləs', 3),
#  ('mənsub', 3),
#  ('con', 3),
#  ('ləşən', 3),
#  ('mərkəz', 3),
#  ('qül', 3),
#  ('imi', 3),
#  ('lət', 3),
#  ('əvvəl', 3),
#  ('da', 3),
#  ('müxtəl', 3),
#  ('ld', 3),
#  ('patel', 3),
#  ('is', 3),
#  ('daha', 3),
#  ('ıq', 3),
#  ('al', 3),
#  ('iyyət', 3),
#  ('hərəkat', 3),
#  ('irgə', 3),
#  ('cənubi', 3),
#  ('yaxın', 3),
#  ('lakin', 3),
#  ('milli', 3),
#  ('iman', 3),
#  ('üz', 2),
#  ('gənc', 2),
#  ('mənşəli', 2),
#  ('amerikalıların', 2),
#  ('biri', 2),
#  ('kişilər', 2),
#  ('qadınlar', 2),
#  ('gündəlik', 2),
#  ('etdirirlər', 2),
#  ('c', 2),
#  ('united', 2),
#  ('states', 2),
#  ('america', 2),
#  ('fəlsəfə', 2),
#  ('doktoru', 2),
#  ('xəzər', 2),
#  ('universitəsi', 2),
#  ('n', 2),
#  ('həyata', 2),
#  ('as', 2),
#  ('the', 2),
#  ('ilkin', 2),
#  ('tərcümə', 2),
#  ('olunmuşdur', 2),
#  ('ştatların', 2),
#  ('qurmaq', 2),
#  ('tarixi', 2),
#  ('m', 2),
#  ('amerikanı', 2),
#  ('x', 2),
#  ('təsəvvür', 2),
#  ('mənə', 2),
#  ('işt', 2),
#  ('rak', 2),
#  ('etməyə', 2),
#  ('yolunda', 2),
#  ('iz', 2),
#  ('nə', 2),
#  ('ro', 2),
#  ('ində', 2),
#  ('səs', 2),
#  ('lan', 2),
#  ('çoxmi', 2),
#  ('ö', 2),
#  ('iy', 2),
#  ('sanqalar', 2),
#  ('h', 2),
#  ('əbu', 2),
#  ('amerikal', 2),
#  ('afr', 2),
#  ('ika', 2),
#  ('du', 2),
#  ('bois', 2),
#  ('din', 2),
#  ('lahın', 2),
#  ('irb', 2),
#  ('şəhərdə', 2),
#  ('ki', 2),
#  ('töhfə', 2),
#  ('başqa', 2),
#  ('məxsus', 2),
#  ('tə', 2),
#  ('lərdə', 2),
#  ('şərqdən', 2),
#  ('qərbə', 2),
#  ('dua', 2),
#  ('etdi', 2),
#  ('uğrunda', 2),
#  ('gənclər', 2),
#  ('tərəfdən', 2),
#  ('edirəm', 2),
#  ('yaşadığ', 2),
#  ('yerdə', 2),
#  ('ləraras', 2),
#  ('amerikaya', 2),
#  ('mühacirlər', 2),
#  ('müxtəlif', 2),
#  ('köhnə', 2),
#  ('qurtulmaq', 2),
#  ('ya', 2),
#  ('cu', 2),
#  ('ci', 2),
#  ('yad', 2),
#  ('kimi', 2),
#  ('töhfələr', 2),
#  ('həmişə', 2),
#  ('bizi', 2),
#  ('müsəlmanların', 2),
#  ('qəbul', 2),
#  ('olunmuş', 2),
#  ('ailə', 2),
#  ('dərəcədə', 2),
#  ('ictimai', 2),
#  ('yemək', 2),
#  ('bəzən', 2),
#  ('səhifədə', 2),
#  ('yuxarıda', 2),
#  ('solda', 2),
#  ('deyə', 2),
#  ('biz', 2),
#  ('behzad', 2),
#  ('ölkəyə', 2),
#  ('hasia', 2),
#  ('kitabın', 1),
#  ('qabığında', 1),
#  ('şəkilləri', 1),
#  ('verilmiş', 1),
#  ('qadınların', 1),
#  ('ikisi', 1),
#  ('müsəlmandır', 1),
#  ('çoxsaylı', 1),
#  ('ərəb', 1),
#  ('yaşadığı', 1),
#  ('icmada', 1),
#  ('miçiqanda', 1),
#  ('detroyt', 1),
#  ('michigan', 1),
#  ('detroityaxınlığında', 1),
#  ('yaşayırlar', 1),
#  ('inamlarını', 1),
#  ('özünəməxsus', 1),
#  ('tərzdə', 1),
#  ('müasir', 1),
#  ('digəri', 1),
#  ('ənənəvi', 1),
#  ('geyimləri', 1),
#  ('ifadə', 1),
#  ('burada', 1),
#  ('basketbol', 1),
#  ('meydançasında', 1),
#  ('çılğıncasına', 1),
#  ('yarışırlar', 1),
#  ('idman', 1),
#  ('növü', 1),
#  ('fərdi', 1),
#  ('qabiliyyət', 1),
#  ('komandanın', 1),
#  ('səyini', 1),
#  ('tələb', 1),
#  ('kitabda', 1),
#  ('uşaqlarla', 1),
#  ('birlikdə', 1),
#  ('müsəlmanlarının', 1),
#  ('tərzini', 1),
#  ('nümayiş', 1),
#  ('department', 1),
#  ('state', 1),
#  ('bureau', 1),
#  ('international', 1),
#  ('information', 1),
#  ('programs', 1),
#  ('being', 1),
#  ('muslim', 1),
#  ('elmi', 1),
#  ('redaktor', 1),
#  ('layihənin', 1),
#  ('koordinatoru', 1),
#  ('nailə', 1),
#  ('süleymanova', 1),
#  ('ilahiyyat', 1),
#  ('tərcüməçi', 1),
#  ('xumar', 1),
#  ('hüseynova', 1),
#  ('redaktorlar', 1),
#  ('elza', 1),
#  ('ismayılova', 1),
#  ('filologiya', 1),
#  ('cabir', 1),
#  ('məmmədov', 1),
#  ('kompüter', 1),
#  ('dizayn', 1),
#  ('zakir', 1),
#  ('yusifoğlu', 1),
#  ('korrektor', 1),
#  ('günay', 1),
#  ('israfilova', 1),
#  ('layihə', 1),
#  ('ştatlarının', 1),
#  ('səfirlyi', 1),
#  ('bağlanmış', 1),
#  ('qrant', 1),
#  ('sazişi', 1),
#  ('əsasında', 1),
#  ('keçirilib', 1),
#  ('this', 1),
#  ('project', 1),
#  ('funded', 1),
#  ('through', 1),
#  ('grant', 1),
#  ('agreement', 1),
#  ('ith', 1),
#  ('embassy', 1),
#  ('nəşriyyat', 1),
#  ('global', 1),
#  ('publishing', 1),
#  ('solutions', 1),
#  ('tərəfinin', 1),
#  ('icazəsi', 1),
#  ('edilmiş', 1),
#  ('nəşr', 1),
#  ('ingilis', 1),
#  ('dilindən', 1),
#  ('khazar', 1),
#  ('university', 1),
#  ('press', 1),
#  ('isbn', 1),
#  ('müsəlmanları', 1),
#  ('bakı', 1),
#  ('nəşriyyatı', 1),
#  ('səh', 1),
#  ('islam', 1),
#  ('müsəlmanlarabş', 1),
#  ('dc', 1),
#  ('dövlət', 1),
#  ('departamenti', 1),
#  ('beynəlxalq', 1),
#  ('informasiya', 1),
#  ('proqramları', 1),
#  ('bürosu', 1),
#  ('giriş', 1),
#  ('amerikalıyam', 1),
#  ('fotooçerk', 1),
#  ('profillər', 1),
#  ('sözlərini', 1),
#  ('deyirlər', 1),
#  ('mənbələr', 1),
#  ('statistik', 1),
#  ('portret', 1),
#  ('yaxınlıqdakı', 1),
#  ('məscidlər', 1),
#  ('mühüm', 1),
#  ('hadisələr', 1),
#  ('biblioqrafiya', 1),
#  ('əlavə', 1),
#  ('bilirdinizmi', 1),
#  ('miniafişa', 1),
#  ('müsəlmanlari', 1),
#  ('y', 1),
#  ('olduqca', 1),
#  ('gözəl', 1),
#  ('imə', 1),
#  ('dey', 1),
#  ('hindistandan', 1),
#  ('övladına', 1),
#  ('içəklənməsi', 1),
#  ('qoymağa', 1),
#  ('oynamağa', 1),
#  ('imkan', 1),
#  ('verdiy', 1),
#  ('sevirəm', 1),
#  ('lk', 1),
#  ('məskunlaşan', 1),
#  ('avropal', 1),
#  ('vinsrop', 1),
#  ('john', 1),
#  ('inthropbu', 1),
#  ('ikr', 1),
#  ('dəstəkləy', 1),
#  ('ındakı', 1),
#  ('lunu', 1),
#  ('həmvətənlər', 1),
#  ('göstərərkən', 1),
#  ('cəmiyyət', 1),
#  ('dünyaya', 1),
#  ('mayak', 1),
#  ('lacaq', 1),
#  ('şəhərə', 1),
#  ('bənzəyəcəyin', 1),
#  ('deyird', 1),
#  ('ümidin', 1),
#  ('kökü', 1),
#  ('xr', 1),
#  ('ist', 1),
#  ('ian', 1),
#  ('lmasında', 1),
#  ('şübhəsiz', 1),
#  ('hündür', 1),
#  ('edirdi', 1),
#  ('lmamışdan', 1),
#  ('boyu', 1),
#  ('son', 1),
#  ('dərəcə', 1),
#  ('lkə', 1),
#  ('lmuşdur', 1),
#  ('doğrudan', 1),
#  ('qərbdə', 1),
#  ('dinə', 1),
#  ('sədaqət', 1),
#  ('ləcə', 1),
#  ('lərə', 1),
#  ('et', 1),
#  ('iqad', 1),
#  ('edi', 1),
#  ('lkəyik', 1),
#  ('indi', 1),
#  ('məscid', 1),
#  ('minarələr', 1),
#  ('yəhudi', 1),
#  ('inaqoqlar', 1),
#  ('ibrani', 1),
#  ('lyazmalar', 1),
#  ('buddist', 1),
#  ('zümzüməsi', 1),
#  ('indu', 1),
#  ('məbədlər', 1),
#  ('əhatə', 1),
#  ('amerıkalıyam', 1),
#  ('faktdır', 1),
#  ('haz', 1),
#  ('ırda', 1),
#  ('təs', 1),
#  ('etiqad', 1),
#  ('yepiskopal', 1),
#  ('sənin', 1),
#  ('üzv', 1),
#  ('indən', 1),
#  ('çoxdur', 1),
#  ('yüz', 1),
#  ('bundan', 1),
#  ('mənşəl', 1),
#  ('görkəml', 1),
#  ('u', 1),
#  ('probleminin', 1),
#  ('rəng', 1),
#  ('problemi', 1),
#  ('lacağı', 1),
#  ('barədə', 1),
#  ('xəbərdar', 1),
#  ('etmişdi', 1),
#  ('inanclar', 1),
#  ('tutacağı', 1),
#  ('eht', 1),
#  ('imal', 1),
#  ('lunurdu', 1),
#  ('ölkəmi', 1),
#  ('lamı', 1),
#  ('imayəsində', 1),
#  ('yaşayan', 1),
#  ('narahat', 1),
#  ('edən', 1),
#  ('məsələ', 1),
#  ('bunlar', 1),
#  ('la', 1),
#  ('lərdi', 1),
#  ('necə', 1),
#  ('üns', 1),
#  ('quracaqlar', 1),
#  ('lsə', 1),
#  ('minarə', 1),
#  ('inaqoq', 1),
#  ('məbəd', 1),
#  ('bölüşməyi', 1),
#  ('öyrənə', 1),
#  ('bi', 1),
#  ('ləcəklərmi', 1),
#  ('düşünürəm', 1),
#  ('dözümlülük', 1),
#  ('hörməti', 1),
#  ('özündə', 1),
#  ('toplayan', 1),
#  ('ənənəsi', 1),
#  ('məsələnin', 1),
#  ('həl', 1),
#  ('xüsus', 1),
#  ('verəcəkdir', 1),
#  ('lərdən', 1),
#  ('toplusudur', 1),
#  ('insanlara', 1),
#  ('dəyər', 1),
#  ('ənənəsinə', 1),
#  ('verməyə', 1),
#  ('musiq', 1),
#  ('not', 1),
#  ('lavə', 1),
#  ('icazə', 1),
#  ('verməsi', 1),
#  ('böyüklüyüdür', 1),
#  ('ıyam', 1),
#  ('qəhrəmanl', 1),
#  ('lardan', 1),
#  ('yoğrulub', 1),
#  ('radəs', 1),
#  ('tabedir', 1),
#  ('məhəmməd', 1),
#  ('peyğəmbərin', 1),
#  ('təbl', 1),
#  ('iğ', 1),
#  ('lamın', 1),
#  ('imlər', 1),
#  ('təzaqa', 1),
#  ('tövhidi', 1),
#  ('haqqı', 1),
#  ('rəhmdi', 1),
#  ('tək', 1),
#  ('lahı', 1),
#  ('ləy', 1),
#  ('ird', 1),
#  ('orta', 1),
#  ('yayı', 1),
#  ('məsc', 1),
#  ('dövrün', 1),
#  ('qahirə', 1),
#  ('bağdad', 1),
#  ('kordovanın', 1),
#  ('tabxanalar', 1),
#  ('im', 1),
#  ('rumi', 1),
#  ('gəz', 1),
#  ('ib', 1),
#  ('dolaşdı', 1),
#  ('ibn', 1),
#  ('rüşdlə', 1),
#  ('ar', 1),
#  ('istotel', 1),
#  ('oxudu', 1),
#  ('nəsir', 1),
#  ('xosrovla', 1),
#  ('iyaya', 1),
#  ('səyahət', 1),
#  ('müstəmləkə', 1),
#  ('dövründə', 1),
#  ('haqqa', 1),
#  ('ədalətə', 1),
#  ('can', 1),
#  ('atdı', 1),
#  ('əbdülqaffar', 1),
#  ('xan', 1),
#  ('xudai', 1),
#  ('idmatqarsla', 1),
#  ('hindistanın', 1),
#  ('azadl', 1),
#  ('ığ', 1),
#  ('yürüşə', 1),
#  ('ıxdı', 1),
#  ('mübar', 1),
#  ('izədə', 1),
#  ('fər', 1),
#  ('ishaq', 1),
#  ('ibrahim', 1),
#  ('musa', 1),
#  ('rahid', 1),
#  ('ömər', 1),
#  ('əzəmətlə', 1),
#  ('durdu', 1),
#  ('qədim', 1),
#  ('baxış', 1),
#  ('ımı', 1),
#  ('p', 1),
#  ('lüra', 1),
#  ('izmə', 1),
#  ('gət', 1),
#  ('rəm', 1),
#  ('amer', 1),
#  ('ikanın', 1),
#  ('ürəyimdə', 1),
#  ('keçməsi', 1),
#  ('fərql', 1),
#  ('icmalara', 1),
#  ('hörmətlə', 1),
#  ('yanaşs', 1),
#  ('ümümi', 1),
#  ('məqsəd', 1),
#  ('naminə', 1),
#  ('ça', 1),
#  ('ışs', 1),
#  ('mi', 1),
#  ('dünya', 1),
#  ('qardaş', 1),
#  ('ədalət', 1),
#  ('ruhunda', 1),
#  ('olsun', 1),
#  ('lsun', 1),
#  ('ümumi', 1),
#  ('məqsədlər', 1),
#  ('çatmaq', 1),
#  ('addımlas', 1),
#  ('müəl', 1),
#  ('eboo', 1),
#  ('inoys', 1),
#  ('ştat', 1),
#  ('ikaqo', 1),
#  ('inois', 1),
#  ('chicagoşəhər', 1),
#  ('fəal', 1),
#  ('göstərən', 1),
#  ('icraedic', 1),
#  ('rektorudur', 1),
#  ('ider', 1),
#  ('kürəsinin', 1),
#  ('guşəsindən', 1),
#  ('gəlmişlər', 1),
#  ('olsalar', 1),
#  ('gəlmə', 1),
#  ('səbəbləri', 1),
#  ('oxşardır', 1),
#  ('tərzindən', 1),
#  ('digərləri', 1),
#  ('tərzi', 1),
#  ('tapmaq', 1),
#  ('zülmdən', 1),
#  ('adətlərin', 1),
#  ('qandalından', 1),
#  ('kasıbçılıqdan', 1),
#  ('sadəcə', 1),
#  ('bəxtlərini', 1),
#  ('sınamaq', 1),
#  ('məqsədilə', 1),
#  ('gəliblər', 1),
#  ('hissəsi', 1),
#  ('avropadan', 1),
#  ('əsrlərdə', 1),
#  ('afrika', 1),
#  ('şərq', 1),
#  ('mərkəzi', 1),
#  ('amerikadan', 1),
#  ('gəlmişdir', 1),
#  ('ümidlə', 1),
#  ('tuturdular', 1),
#  ('vaxt', 1),
#  ('ümidləri', 1),
#  ('cüzi', 1),
#  ('təəssüratları', 1),
#  ('qarışıq', 1),
#  ('olurdu', 1),
#  ('yerləşdikləri', 1),
#  ('işçi', 1),
#  ('qüvvəsinə', 1),
#  ('kəskin', 1),
#  ('ehtiyac', 1),
#  ('olduğunu', 1),
#  ('görürdülər', 1),
#  ('gələnlərin', 1),
#  ('adət', 1),
#  ('ənənələrinə', 1),
#  ('bələd', 1),
#  ('olmayanlar', 1),
#  ('onlarla', 1),
#  ('adamlar', 1),
#  ('davranır', 1),
#  ('vaxtsa', 1),
#  ('əsl', 1),
#  ('olacağına', 1),
#  ('inanmırdılar', 1),
#  ('yanılırdılar', 1),
#  ('azadlıqları', 1),
#  ('dinləri', 1),
#  ('zəhmətkeşlikləri', 1),
#  ('mühacir', 1),
#  ('dəstəsi', 1),
#  ('cəmiyyətinə', 1),
#  ('fərqli', 1),
#  ('verir', 1),
#  ('cəmiyyətimizi', 1),
#  ('mədəniyyətimizi', 1),
#  ('zənginləşdirir', 1),
#  ('dinamiklik', 1),
#  ('inkişaf', 1),
#  ('mənasını', 1),
#  ('bildirən', 1),
#  ('birbirimizə', 1),
#  ('bağlayan', 1),
#  ('sözü', 1),
#  ('formalaşdırırlar', 1),
#  ('gün', 1),
#  ('hekayəsidir', 1),
#  ('abdül', 1),
#  ('məcdə', 1),
#  ('əlsaadi', 1),
#  ('abdul', 1),
#  ('and', 1),
#  ('majda', 1),
#  ('alsaadivolmart', 1),
#  ('mağazasında', 1),
#  ('dearborn', 1),
#  ('miçiqan', 1),
#  ('ildə', 1),
#  ('immiqrasiya', 1),
#  ('haqqında', 1),
#  ('qanun', 1),
#  ('məlum', 1),
#  ('axınında', 1),
#  ('dəyişikliklər', 1),
#  ('yaratdı', 1),
#  ('artıq', 1),
#  ('mənşəyə', 1),
#  ('müəyyən', 1),
#  ('bölgü', 1),
#  ('kimlərin', 1),
#  ('gələ', 1),
#  ('biləcəyini', 1),
#  ('müəyyənləşdirmirdi', 1),
#  ('yerini', 1),
#  ('münasibətləri', 1),
#  ('iş', 1),
#  ('bacarıqları', 1),
#  ('kateqoriyalar', 1),
#  ('tutdu', 1),
#  ('dəyişikliklə', 1),
#  ('mühacirlərin', 1),
#  ('sayı', 1),
#  ('artdı', 1),
#  ('ilk', 1),
#  ('nəzərə', 1),
#  ('çarpacaq', 1),
#  ('qrupu', 1),
#  ('ştatlara', 1),
#  ('daxil', 1),
#  ('oldu', 1),
#  ('gələn', 1),
#  ('immiqrantlarından', 1),
#  ('fərqlənirdilər', 1),
#  ('amma', 1),
#  ('bugünkü', 1),
#  ('sosial', 1),
#  ('iqtisadi', 1),
#  ('siyasi', 1),
#  ('həyatında', 1),
#  ('yerlərini', 1),
#  ('tapmaqda', 1),
#  ('immiqrantların', 1),
#  ('problemləri', 1),
#  ('üzləşdilər', 1),
#  ('iki', 1),
#  ('bacıya', 1),
#  ('bondaiyə', 1),
#  ('assia', 1),
#  ('boundaouidiqqət', 1),
#  ('yetirin', 1),
#  ('valideynləri', 1),
#  ('əlcəzairdəndirlər', 1),
#  ('qızlar', 1),
#  ('illinoysda', 1),
#  ('çikaqo', 1),
#  ('yaxınlığında', 1),
#  ('boyabaşa', 1),
#  ('çatmışlar', 1),
#  ('radionun', 1),
#  ('national', 1),
#  ('public', 1),
#  ('radio', 1),
#  ('nprverdiyi', 1),
#  ('məlumata', 1),
#  ('uşaqlar', 1),
#  ('naykloden', 1),
#  ('nickelodeon', 1),
#  ('əlcəzirə', 1),
#  ('xəbərlər', 1),
#  ('kanallarına', 1),
#  ('baxaraq', 1),
#  ('böyümüşlər', 1),
#  ('kentukki', 1),
#  ('tabakası', 1),
#  ('yeməkxanasını', 1),
#  ('sevimli', 1),
#  ('falafel', 1),
#  ('restoranlarını', 1),
#  ('seçirdilər', 1),
#  ('şərqə', 1),
#  ('aid', 1),
#  ('lobyadan', 1),
#  ('paxlalı', 1),
#  ('bitkilərdən', 1),
#  ('hazırlanmış', 1),
#  ('ədviyyatlı', 1),
#  ('red', 1),
#  ('həyatfoto', 1),
#  ('qalereya', 1),
#  ('üzbəüz', 1),
#  ('sədəf', 1),
#  ('butt', 1),
#  ('sadaf', 1),
#  ('butthicabını', 1),
#  ('səliqəyə', 1),
#  ('salarkən', 1),
#  ('aşağıda', 1),
#  ('konqresin', 1),
#  ('üzvləri', 1),
#  ('vaşinqtonda', 1),
#  ('kapitolidə', 1),
#  ('fasilə', 1),
#  ('vaxtı', 1),
#  ('dizayner', 1),
#  ('bruk', 1),
#  ('səməd', 1),
#  ('brook', 1),
#  ('samadfabrik', 1),
#  ('nümunələrini', 1),
#  ('müqayisə', 1),
#  ('edərkən', 1),
#  ('sağda', 1),
#  ('təhqiq', 1),
#  ('abbasi', 1),
#  ('tahqiq', 1),
#  ('abbasiözünün', 1),
#  ('nyu', 1),
#  ('cersidə', 1),
#  ('yunion', 1),
#  ('sitidəki', 1),
#  ('union', 1),
#  ('city', 1),
#  ('ne', 1),
#  ('jerseyparça', 1),
#  ('dükanında', 1),
#  ('yaşlı', 1),
#  ('radioya', 1),
#  ('müsahibəsində', 1),
#  ('demişdir', 1),
#  ('bilərik', 1),
#  ('şeydən', 1),
#  ('müsəlmanıq', 1),
#  ('elə', 1),
#  ('gəlir', 1),
#  ('fərqləndirən', 1),
#  ('budur', 1),
#  ('ölkədə', 1),
#  ('məsələn', 1),
#  ('hansı', 1),
#  ('ölkəsində', 1),
#  ('olduğumuzu', 1),
#  ('bilirik', 1),
#  ('hekayəsi', 1),
#  ('diqqətəlayiqdir', 1),
#  ('qədər', 1),
#  ('yox', 1),
#  ('etnik', 1),
#  ('dini', 1),
#  ('kombinasiyanın', 1),
#  ('vəhdətindən', 1),
#  ('yaranmış', 1),
#  ('nəsil', 1),
#  ('özünü', 1),
#  ('hesab', 1),
#  ('ateizmin', 1),
#  ('edilməsi', 1),
#  ('yollanan', 1),
#  ('əhvalatları', 1),
#  ('əsərinin', 1),
#  ('müəllifi', 1),
#  ('iran', 1),
#  ('yağmaiyan', 1),
#  ('yaghmaianmüşahidələrinə', 1),
#  ('əsasən', 1),
#  ('demişdi', 1),
#  ('qeyrimüsəlmanlar', 1),
#  ('ümidlər', 1),
#  ('məkanı', 1),
#  ('olmuşdur', 1),
#  ('hələ', 1),
#  ('gəlməsinin', 1),
#  ('səbəbi', 1),
#  ('onlara', 1),
#  ('ölkələrində', 1),
#  ('tapmadıqlarını', 1),
#  ('təklif', 1),
#  ('etməsidir', 1),
#  ('ənənəsini', 1),
#  ('davam', 1),
#  ('fərd', 1),
#  ('olaraq', 1),
#  ('nəslə', 1),
#  ('deyil', 1),
#  ('kəsə', 1),
#  ('azadlıq', 1),
#  ('imkanlar', 1),
#  ('bərabər', 1),
#  ('hüquqlar', 1),
#  ('ideyası', 1),
#  ('üzərində', 1),
#  ('qurulmuş', 1),
#  ('müqayisəedilməz', 1),
#  ('verirlər', 1),
#  ('tarixçi', 1),
#  ('dinər', 1),
#  ('dineryazır', 1),
#  ('boyunca', 1),
#  ('dünyanın', 1),
#  ('guşələrindən', 1),
#  ('təcrübəsinə', 1),
#  ('meyil', 1),
#  ('ediblər', 1),
#  ('həmin', 1),
#  ('dövrdə', 1)]

# %%
# store word frequencies in a txt file as word    frequency
with open('../outputs/word_frequencies.txt', mode='w', encoding='utf-8') as file:
    for word, frequency in word_to_frequency.items():
        file.write(f"{word}\t{frequency}\n")

# %%
# initialize model
model = Word2Vec(tokenized_sentences, vector_size=32, window=5, min_count=1, workers=12)

# %%
model.save("../outputs/word2vec.model")
